# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import numpy as np
import requests
import json
import os
import matplotlib.pyplot as plt

# Import API key
from api_keys import weather_api_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = os.path.join('output_data/cities.csv')

# Display sample data
city_data_df = pd.read_csv(csv_file)
city_data_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0          0           arish  31.1316   33.7984     22.51        73
# 1          1     salinopolis  -0.6136  -47.3561     27.04        82
# 2          2  ribeira grande  38.5167  -28.7000     13.76        78
# 3          3         kirando  -7.4167   30.6000     22.43        85
# 4          4          neiafu -18.6500 -173.9833     28.38        61
# ..       ...             ...      ...       ...       ...       ...
# 572      572          heyuan  23.7333  114.6833     24.86        71
# 573      573      priargunsk  50.3691  119.1012     -9.55        42
# 574      574  yuzhno-kurilsk  44.0306  145.8556      8.54        81
# 575      575   joao pinheiro -17.7425  -46.1725     24.90        49
# 576      576         marsala  37.7966   12.4352     20.97        78
#
#      Cloudiness  Wind Speed Country        Date
# 0             0        1.43      EG  1699235268
# 1            92        4.66      BR  1699235268
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City"
)

# Display the map
map_plot_1

# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# # Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
weather_condition = city_data_df[(city_data_df['Max Temp']>=21) & (city_data_df['Max Temp']<=23)]
weather_condition = weather_condition[weather_condition['Humidity'] <= 78]
weather_condition = weather_condition[weather_condition['Cloudiness'] <= 10]
weather_condition = weather_condition[weather_condition['Wind Speed'] <= 10]
weather_condition
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0          0           arish  31.1316   33.7984     22.51        73
# 88        88          santee  32.8384 -116.9739     22.06        61
# 158      158           nohar  29.1833   74.7667     21.48        24
# 191      191            tura  25.5198   90.2201     21.42        76
# 196      196        chicoana -25.1009  -65.5331     22.03        43
# 266      266       al badari  26.9926   31.4155     21.08        37
# 312      312      beitbridge -22.2167   30.0000     22.65        48
# 315      315      ermoupolis  37.4423   24.9425     21.39        73
# 404      404         awjilah  29.1081   21.2869     22.61        27
# 472      472  guerrero negro  27.9769 -114.0611     21.89        59
# 479      479      ain sukhna  29.6002   32.3167     21.31        52
# 484      484  hassi messaoud  31.6804    6.0729     22.86        22
# 547      547  general pinedo -27.3167  -61.2833     21.10        63
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = weather_condition[["City", "Country", "Lat", "Lng", "Humidity"]]
hotel_df
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# YOUR CODE HERE
# Out:
# C:\Users\odunz\AppData\Local\Temp\ipykernel_60440\2623681391.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ""
#                City Country      Lat       Lng  Humidity Hotel Name
# 0             arish      EG  31.1316   33.7984        73
# 88           santee      US  32.8384 -116.9739        61
# 158           nohar      IN  29.1833   74.7667        24
# 191            tura      IN  25.5198   90.2201        76
# 196        chicoana      AR -25.1009  -65.5331        43
# 266       al badari      EG  26.9926   31.4155        37
# 312      beitbridge      ZW -22.2167   30.0000        48
# 315      ermoupolis      GR  37.4423   24.9425        73
# 404         awjilah      LY  29.1081   21.2869        27
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
weather_api_key
# Out:
# 'ae5fe683d37f2e93d18d887f8f267b94'

# %%
# Set parameters to search for a hotel
params = {
    "keyword": "hotel",
    "radius": 5000,
    "key": weather_api_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    Lat = row["Lat"]
    Lng = row["Lng"]  
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"{Lat},{Lng}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty 
    # Convert the API response to JSON format
    print(f"Retrieving results for city: {row['City']}")
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["feautures"][0]["properties"]["name"]
        
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Retrieving results for city: arish
# arish - nearest hotel: No hotel found
# Retrieving results for city: santee
# santee - nearest hotel: No hotel found
# Retrieving results for city: nohar
# nohar - nearest hotel: No hotel found
# Retrieving results for city: tura
# tura - nearest hotel: No hotel found
# Retrieving results for city: chicoana
# chicoana - nearest hotel: No hotel found
# Retrieving results for city: al badari
# al badari - nearest hotel: No hotel found
# Retrieving results for city: beitbridge
# beitbridge - nearest hotel: No hotel found
# Retrieving results for city: ermoupolis
# ermoupolis - nearest hotel: No hotel found
# Retrieving results for city: awjilah
# awjilah - nearest hotel: No hotel found
# Retrieving results for city: guerrero negro
# guerrero negro - nearest hotel: No hotel found
# Retrieving results for city: ain sukhna
# ain sukhna - nearest hotel: No hotel found
# Retrieving results for city: hassi messaoud
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Hotel Name",
    scale = 0.5,
    color = "Country"
)
# Display the map
map_plot_2
# YOUR CODE HERE
# Out:
# WARNING:param.GeoPointPlot01931: Specified size dim transform (np.sqrt(dim('Hotel Name'))*0.5) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Country)
